# %%
# run this after
#     ./1_populate_tables.ipynb

# %%
from numpy import std, mean
import sqlite3
db_fname = '../../hmt.db'

features = [
    'pitch_min', 'pitch_max', 'pitch_mean', 'pitch_std', 
    'rate_syl', 'rate_vcd',
    'intensity_min', 'intensity_max', 'intensity_mean', 'intensity_std', 
    'jitter', 'shimmer', 'nhr'
]

# %%
print('normalizing; stats before update: ', end='\n\n')
with sqlite3.connect(db_fname) as conn:
    c = conn.cursor()
    
    c.execute('SELECT spk_id FROM speakers ORDER BY spk_id;')
    spk_ids = [v[0] for v in c.fetchall()]
    
    for spk_id in spk_ids:
        print('spk_id: %d' % spk_id)
        for f in features:
            # chunks with non-null values for current feature and speaker
            sql_fragment = \
                'FROM   chunks chu ' \
                'JOIN   turns tur ' \
                'ON     chu.tur_id == tur.tur_id ' \
                'JOIN   tasks tsk ' \
                'ON     tur.tsk_id == tsk.tsk_id ' \
                'JOIN   sessions ses ' \
                'ON     tsk.ses_id == ses.ses_id ' \
                'JOIN   speakers spk_a ' \
                'ON     ses.spk_id_a == spk_a.spk_id ' \
                'JOIN   speakers spk_b ' \
                'ON     ses.spk_id_b == spk_b.spk_id ' \
                'WHERE  CASE ' \
                '           WHEN tsk.a_or_b == "A" AND ' \
                '                tur.speaker_role == "d" ' \
                '           THEN spk_a.spk_id ' \
                '           WHEN tsk.a_or_b == "B" AND ' \
                '                tur.speaker_role == "f" ' \
                '           THEN spk_a.spk_id ' \
                '           ELSE spk_b.spk_id ' \
                '       END == ' + str(spk_id) + ' ' \
                'AND    ' + f + ' IS NOT NULL'

            # non-null feature values for current feature and speaker
            sql_stmt1 = \
                'SELECT ' + f + ' ' + sql_fragment
                
            # normalization for current feature and speaker
            # using given means, std
            sql_stmt2 = \
                'UPDATE chunks SET ' + ('%s = (%s-?)/?' % (f, f)) + ' ' \
                'WHERE  chu_id IN (' \
                    'SELECT chu.chu_id ' + sql_fragment + ')'
            
            c.execute(sql_stmt1,)
            
            data = [v[0] for v in c.fetchall()]
            stats = (mean(data), std(data) if std(data) != 0.0 else 1.0) 
            
            print('\t%s, mean: %.3f, std: %.3f' % (f, stats[0], stats[1]))
            c.execute(sql_stmt2, (stats[0], stats[1]))
        conn.commit()
        print('\n\n')
# Out:
# normalizing; stats before update:
#
# spk_id: 1
# 	pitch_min, mean: 106.017, std: 15.098
# 	pitch_max, mean: 271.890, std: 172.264
# 	pitch_mean, mean: 139.345, std: 22.275
# 	pitch_std, mean: 36.179, std: 41.972
# 	rate_syl, mean: 5.801, std: 2.588
# 	rate_vcd, mean: 0.621, std: 0.217
# 	intensity_min, mean: 43.295, std: 7.651
# 	intensity_max, mean: 65.518, std: 4.989
# 	intensity_mean, mean: 57.303, std: 4.555
# 	intensity_std, mean: 5.943, std: 2.486
# 	jitter, mean: 0.013, std: 0.009
# 	shimmer, mean: 0.110, std: 0.039
# 	nhr, mean: 0.159, std: 0.097
#
#
#
# spk_id: 2
# 	pitch_min, mean: 93.369, std: 33.741
# 	pitch_max, mean: 304.558, std: 180.714
# 	pitch_mean, mean: 130.151, std: 46.222
# 	pitch_std, mean: 44.991, std: 42.817
# 	rate_syl, mean: 5.904, std: 2.620
# 	rate_vcd, mean: 0.479, std: 0.226
# 	intensity_min, mean: 46.111, std: 7.183
# 	intensity_max, mean: 74.245, std: 5.105
# 	intensity_mean, mean: 64.513, std: 3.962
# 	intensity_std, mean: 7.189, std: 2.429
# 	jitter, mean: 0.020, std: 0.014
# 	shimmer, mean: 0.110, std: 0.052
# 	nhr, mean: 0.192, std: 0.103
#
#
#
# spk_id: 3
# 	pitch_min, mean: 111.420, std: 17.822
# 	pitch_max, mean: 264.155, std: 146.883
# 	pitch_mean, mean: 143.673, std: 23.462
# 	pitch_std, mean: 28.674, std: 28.691
# 	rate_syl, mean: 5.198, std: 2.052
# 	rate_vcd, mean: 0.610, std: 0.163
# 	intensity_min, mean: 45.342, std: 6.633
# 	intensity_max, mean: 75.226, std: 4.055
# 	intensity_mean, mean: 64.812, std: 3.416
# 	intensity_std, mean: 8.113, std: 2.235
# 	jitter, mean: 0.013, std: 0.008
# 	shimmer, mean: 0.096, std: 0.033
# 	nhr, mean: 0.155, std: 0.075
#
#
#
# spk_id: 4
# 	pitch_min, mean: 90.002, std: 11.708
# 	pitch_max, mean: 271.209, std: 159.524
# 	pitch_mean, mean: 123.091, std: 23.956
# 	pitch_std, mean: 39.622, std: 37.152
# 	rate_syl, mean: 4.483, std: 1.655
# 	rate_vcd, mean: 0.613, std: 0.179
# 	intensity_min, mean: 47.576, std: 6.645
# 	intensity_max, mean: 72.661, std: 4.956
# 	intensity_mean, mean: 64.307, std: 3.769
# 	intensity_std, mean: 6.524, std: 2.296
# 	jitter, mean: 0.016, std: 0.008
# 	shimmer, mean: 0.108, std: 0.034
# 	nhr, mean: 0.167, std: 0.081
#
#
#
# spk_id: 5
# 	pitch_min, mean: 117.243, std: 48.078
# 	pitch_max, mean: 397.550, std: 126.869
# 	pitch_mean, mean: 217.525, std: 34.069
# 	pitch_std, mean: 60.451, std: 29.477
# 	rate_syl, mean: 5.704, std: 1.863
# 	rate_vcd, mean: 0.702, std: 0.140
# 	intensity_min, mean: 43.286, std: 6.124
# 	intensity_max, mean: 65.504, std: 4.306
# 	intensity_mean, mean: 57.395, std: 2.909
# 	intensity_std, mean: 5.522, std: 1.784
# 	jitter, mean: 0.011, std: 0.004
# 	shimmer, mean: 0.129, std: 0.031
# 	nhr, mean: 0.157, std: 0.074
#
#
#
# spk_id: 6
# 	pitch_min, mean: 104.265, std: 14.694
# 	pitch_max, mean: 276.777, std: 149.155
# 	pitch_mean, mean: 138.254, std: 24.243
# 	pitch_std, mean: 35.204, std: 33.005
# 	rate_syl, mean: 5.651, std: 1.865
# 	rate_vcd, mean: 0.572, std: 0.177
# 	intensity_min, mean: 42.682, std: 6.342
# 	intensity_max, mean: 70.410, std: 5.223
# 	intensity_mean, mean: 60.564, std: 3.632
# 	intensity_std, mean: 6.944, std: 1.998
# 	jitter, mean: 0.013, std: 0.005
# 	shimmer, mean: 0.108, std: 0.031
# 	nhr, mean: 0.190, std: 0.088
#
#
#
# spk_id: 100
# 	pitch_min, mean: 78.907, std: 6.279
# 	pitch_max, mean: 189.051, std: 125.069
# 	pitch_mean, mean: 105.308, std: 17.794
# 	pitch_std, mean: 24.668, std: 23.577
# 	rate_syl, mean: 5.728, std: 1.986
# 	rate_vcd, mean: 0.509, std: 0.214
# 	intensity_min, mean: 44.706, std: 8.307
# 	intensity_max, mean: 74.495, std: 5.812
# 	intensity_mean, mean: 64.425, std: 4.528
# 	intensity_std, mean: 7.356, std: 2.268
# 	jitter, mean: 0.020, std: 0.006
# 	shimmer, mean: 0.110, std: 0.027
# 	nhr, mean: 0.168, std: 0.076
#
#
#
# spk_id: 101
# 	pitch_min, mean: 115.811, std: 45.891
# 	pitch_max, mean: 308.101, std: 112.553
# 	pitch_mean, mean: 180.274, std: 37.133
# 	pitch_std, mean: 39.359, std: 25.321
# 	rate_syl, mean: 4.058, std: 2.086
# 	rate_vcd, mean: 0.652, std: 0.208
# 	intensity_min, mean: 43.581, std: 9.857
# 	intensity_max, mean: 70.461, std: 5.565
# 	intensity_mean, mean: 61.740, std: 5.388
# 	intensity_std, mean: 6.991, std: 2.839
# 	jitter, mean: 0.013, std: 0.009
# 	shimmer, mean: 0.100, std: 0.052
# 	nhr, mean: 0.135, std: 0.111
#
#
#
# spk_id: 102
# 	pitch_min, mean: 120.207, std: 44.578
# 	pitch_max, mean: 364.761, std: 142.323
# 	pitch_mean, mean: 201.485, std: 32.587
# 	pitch_std, mean: 51.384, std: 31.977
# 	rate_syl, mean: 4.503, std: 1.429
# 	rate_vcd, mean: 0.559, std: 0.180
# 	intensity_min, mean: 39.633, std: 7.544
# 	intensity_max, mean: 69.765, std: 4.757
# 	intensity_mean, mean: 58.162, std: 3.848
# 	intensity_std, mean: 7.994, std: 2.334
# 	jitter, mean: 0.012, std: 0.005
# 	shimmer, mean: 0.102, std: 0.030
# 	nhr, mean: 0.159, std: 0.084
#
#
#
# spk_id: 103
# 	pitch_min, mean: 117.875, std: 48.578
# 	pitch_max, mean: 363.628, std: 131.572
# 	pitch_mean, mean: 205.683, std: 33.276
# 	pitch_std, mean: 52.053, std: 31.646
# 	rate_syl, mean: 5.108, std: 1.773
# 	rate_vcd, mean: 0.652, std: 0.177
# 	intensity_min, mean: 40.854, std: 7.585
# 	intensity_max, mean: 68.587, std: 3.755
# 	intensity_mean, mean: 59.213, std: 3.921
# 	intensity_std, mean: 6.873, std: 2.165
# 	jitter, mean: 0.010, std: 0.005
# 	shimmer, mean: 0.093, std: 0.030
# 	nhr, mean: 0.127, std: 0.085
#
#
#
# spk_id: 104
# 	pitch_min, mean: 122.818, std: 38.865
# 	pitch_max, mean: 354.352, std: 130.508
# 	pitch_mean, mean: 206.137, std: 31.658
# 	pitch_std, mean: 44.980, std: 22.925
# 	rate_syl, mean: 5.490, std: 1.683
# 	rate_vcd, mean: 0.699, std: 0.139
# 	intensity_min, mean: 42.267, std: 7.201
# 	intensity_max, mean: 71.174, std: 4.265
# 	intensity_mean, mean: 61.348, std: 2.932
# 	intensity_std, mean: 6.795, std: 2.027
# 	jitter, mean: 0.011, std: 0.004
# 	shimmer, mean: 0.101, std: 0.026
# 	nhr, mean: 0.124, std: 0.057
#
#
#
# spk_id: 105
# 	pitch_min, mean: 120.382, std: 46.307
# 	pitch_max, mean: 337.263, std: 129.783
# 	pitch_mean, mean: 204.851, std: 39.172
# 	pitch_std, mean: 47.634, std: 28.481
# 	rate_syl, mean: 5.280, std: 1.857
# 	rate_vcd, mean: 0.567, std: 0.176
# 	intensity_min, mean: 42.647, std: 8.015
# 	intensity_max, mean: 72.124, std: 5.741
# 	intensity_mean, mean: 61.304, std: 4.819
# 	intensity_std, mean: 7.344, std: 2.363
# 	jitter, mean: 0.014, std: 0.007
# 	shimmer, mean: 0.107, std: 0.034
# 	nhr, mean: 0.173, std: 0.090
#
#
#
# spk_id: 106
# 	pitch_min, mean: 131.573, std: 43.783
# 	pitch_max, mean: 285.407, std: 101.039
# 	pitch_mean, mean: 195.197, std: 25.886
# 	pitch_std, mean: 32.093, std: 20.100
# 	rate_syl, mean: 6.066, std: 1.869
# 	rate_vcd, mean: 0.709, std: 0.161
# 	intensity_min, mean: 43.738, std: 8.423
# 	intensity_max, mean: 71.550, std: 5.199
# 	intensity_mean, mean: 62.004, std: 4.049
# 	intensity_std, mean: 6.829, std: 2.305
# 	jitter, mean: 0.011, std: 0.004
# 	shimmer, mean: 0.106, std: 0.032
# 	nhr, mean: 0.130, std: 0.073
#
#
#
# spk_id: 107
# 	pitch_min, mean: 113.508, std: 27.231
# 	pitch_max, mean: 262.964, std: 109.902
# 	pitch_mean, mean: 170.202, std: 37.692
# 	pitch_std, mean: 36.160, std: 25.825
# 	rate_syl, mean: 5.516, std: 1.847
# 	rate_vcd, mean: 0.577, std: 0.218
# 	intensity_min, mean: 48.449, std: 7.310
# 	intensity_max, mean: 78.936, std: 5.352
# 	intensity_mean, mean: 67.720, std: 3.842
# 	intensity_std, mean: 7.818, std: 2.186
# 	jitter, mean: 0.015, std: 0.008
# 	shimmer, mean: 0.123, std: 0.048
# 	nhr, mean: 0.182, std: 0.102
#
#
#
# spk_id: 110
# 	pitch_min, mean: 111.586, std: 21.326
# 	pitch_max, mean: 268.915, std: 114.444
# 	pitch_mean, mean: 155.751, std: 19.616
# 	pitch_std, mean: 32.367, std: 18.044
# 	rate_syl, mean: 5.482, std: 1.975
# 	rate_vcd, mean: 0.626, std: 0.158
# 	intensity_min, mean: 40.368, std: 6.785
# 	intensity_max, mean: 68.948, std: 4.167
# 	intensity_mean, mean: 59.594, std: 3.798
# 	intensity_std, mean: 6.954, std: 1.897
# 	jitter, mean: 0.015, std: 0.007
# 	shimmer, mean: 0.106, std: 0.036
# 	nhr, mean: 0.144, std: 0.074
#
#
#
# spk_id: 111
# 	pitch_min, mean: 129.829, std: 39.281
# 	pitch_max, mean: 336.737, std: 147.793
# 	pitch_mean, mean: 189.448, std: 25.039
# 	pitch_std, mean: 42.551, std: 30.668
# 	rate_syl, mean: 4.412, std: 1.628
# 	rate_vcd, mean: 0.691, std: 0.157
# 	intensity_min, mean: 42.769, std: 8.462
# 	intensity_max, mean: 69.757, std: 4.247
# 	intensity_mean, mean: 61.085, std: 3.994
# 	intensity_std, mean: 7.150, std: 2.718
# 	jitter, mean: 0.011, std: 0.005
# 	shimmer, mean: 0.087, std: 0.032
# 	nhr, mean: 0.098, std: 0.065
#
#
#
# spk_id: 112
# 	pitch_min, mean: 142.014, std: 50.033
# 	pitch_max, mean: 364.558, std: 121.811
# 	pitch_mean, mean: 224.328, std: 28.984
# 	pitch_std, mean: 42.135, std: 25.183
# 	rate_syl, mean: 5.397, std: 1.809
# 	rate_vcd, mean: 0.660, std: 0.151
# 	intensity_min, mean: 40.278, std: 8.136
# 	intensity_max, mean: 69.269, std: 3.787
# 	intensity_mean, mean: 60.135, std: 3.446
# 	intensity_std, mean: 7.268, std: 2.353
# 	jitter, mean: 0.012, std: 0.006
# 	shimmer, mean: 0.090, std: 0.031
# 	nhr, mean: 0.119, std: 0.071
#
#
#
# spk_id: 113
# 	pitch_min, mean: 144.015, std: 51.814
# 	pitch_max, mean: 382.560, std: 133.762
# 	pitch_mean, mean: 213.367, std: 29.486
# 	pitch_std, mean: 50.135, std: 30.162
# 	rate_syl, mean: 5.059, std: 2.064
# 	rate_vcd, mean: 0.679, std: 0.178
# 	intensity_min, mean: 42.105, std: 8.221
# 	intensity_max, mean: 69.914, std: 4.404
# 	intensity_mean, mean: 60.262, std: 3.911
# 	intensity_std, mean: 7.367, std: 2.727
# 	jitter, mean: 0.010, std: 0.004
# 	shimmer, mean: 0.095, std: 0.030
# 	nhr, mean: 0.122, std: 0.080
#
#
#
# spk_id: 114
# 	pitch_min, mean: 106.617, std: 19.111
# 	pitch_max, mean: 235.406, std: 105.691
# 	pitch_mean, mean: 150.368, std: 19.551
# 	pitch_std, mean: 27.019, std: 14.618
# 	rate_syl, mean: 5.893, std: 2.228
# 	rate_vcd, mean: 0.663, std: 0.152
# 	intensity_min, mean: 46.233, std: 7.889
# 	intensity_max, mean: 76.588, std: 5.457
# 	intensity_mean, mean: 65.538, std: 3.324
# 	intensity_std, mean: 7.601, std: 2.503
# 	jitter, mean: 0.015, std: 0.006
# 	shimmer, mean: 0.109, std: 0.025
# 	nhr, mean: 0.128, std: 0.074
#
#
#
# spk_id: 115
# 	pitch_min, mean: 104.829, std: 16.627
# 	pitch_max, mean: 268.979, std: 144.954
# 	pitch_mean, mean: 148.354, std: 18.691
# 	pitch_std, mean: 32.170, std: 23.451
# 	rate_syl, mean: 6.124, std: 1.901
# 	rate_vcd, mean: 0.650, std: 0.136
# 	intensity_min, mean: 47.813, std: 6.912
# 	intensity_max, mean: 79.859, std: 5.340
# 	intensity_mean, mean: 68.930, std: 4.186
# 	intensity_std, mean: 7.630, std: 1.760
# 	jitter, mean: 0.015, std: 0.004
# 	shimmer, mean: 0.104, std: 0.023
# 	nhr, mean: 0.130, std: 0.058
#
#
#
# spk_id: 116
# 	pitch_min, mean: 106.848, std: 38.437
# 	pitch_max, mean: 311.290, std: 122.878
# 	pitch_mean, mean: 187.339, std: 32.004
# 	pitch_std, mean: 43.070, std: 24.261
# 	rate_syl, mean: 4.853, std: 1.909
# 	rate_vcd, mean: 0.626, std: 0.176
# 	intensity_min, mean: 41.348, std: 8.139
# 	intensity_max, mean: 72.631, std: 5.012
# 	intensity_mean, mean: 62.250, std: 3.945
# 	intensity_std, mean: 7.774, std: 2.530
# 	jitter, mean: 0.013, std: 0.011
# 	shimmer, mean: 0.098, std: 0.032
# 	nhr, mean: 0.130, std: 0.068
#
#
#
# spk_id: 117
# 	pitch_min, mean: 100.240, std: 19.460
# 	pitch_max, mean: 269.210, std: 145.937
# 	pitch_mean, mean: 141.851, std: 24.269
# 	pitch_std, mean: 36.494, std: 30.062
# 	rate_syl, mean: 4.799, std: 1.983
# 	rate_vcd, mean: 0.624, std: 0.169
# 	intensity_min, mean: 43.278, std: 7.404
# 	intensity_max, mean: 72.483, std: 6.535
# 	intensity_mean, mean: 61.890, std: 4.636
# 	intensity_std, mean: 7.777, std: 2.543
# 	jitter, mean: 0.016, std: 0.005
# 	shimmer, mean: 0.100, std: 0.030
# 	nhr, mean: 0.148, std: 0.079
#
#
#
# spk_id: 118
# 	pitch_min, mean: 108.739, std: 41.071
# 	pitch_max, mean: 351.673, std: 151.859
# 	pitch_mean, mean: 181.561, std: 24.214
# 	pitch_std, mean: 42.301, std: 26.534
# 	rate_syl, mean: 4.768, std: 1.699
# 	rate_vcd, mean: 0.668, std: 0.154
# 	intensity_min, mean: 38.277, std: 7.419
# 	intensity_max, mean: 69.535, std: 5.289
# 	intensity_mean, mean: 59.436, std: 3.824
# 	intensity_std, mean: 7.355, std: 2.254
# 	jitter, mean: 0.011, std: 0.005
# 	shimmer, mean: 0.090, std: 0.030
# 	nhr, mean: 0.105, std: 0.074
#
#
#
# spk_id: 119
# 	pitch_min, mean: 131.343, std: 35.854
# 	pitch_max, mean: 316.254, std: 145.221
# 	pitch_mean, mean: 179.383, std: 22.420
# 	pitch_std, mean: 36.215, std: 31.217
# 	rate_syl, mean: 5.154, std: 1.992
# 	rate_vcd, mean: 0.695, std: 0.162
# 	intensity_min, mean: 39.147, std: 7.753
# 	intensity_max, mean: 64.870, std: 4.199
# 	intensity_mean, mean: 56.455, std: 3.678
# 	intensity_std, mean: 6.359, std: 2.235
# 	jitter, mean: 0.011, std: 0.005
# 	shimmer, mean: 0.092, std: 0.037
# 	nhr, mean: 0.103, std: 0.076
#
#
#
# spk_id: 200
# 	pitch_min, mean: 110.672, std: 42.652
# 	pitch_max, mean: 335.259, std: 148.960
# 	pitch_mean, mean: 176.557, std: 30.122
# 	pitch_std, mean: 48.989, std: 31.271
# 	rate_syl, mean: 5.200, std: 2.222
# 	rate_vcd, mean: 0.647, std: 0.173
# 	intensity_min, mean: 41.660, std: 8.214
# 	intensity_max, mean: 68.775, std: 5.029
# 	intensity_mean, mean: 59.536, std: 4.552
# 	intensity_std, mean: 6.885, std: 2.349
# 	jitter, mean: 0.013, std: 0.006
# 	shimmer, mean: 0.105, std: 0.040
# 	nhr, mean: 0.130, std: 0.078
#
#
#
# spk_id: 201
# 	pitch_min, mean: 108.461, std: 16.227
# 	pitch_max, mean: 325.765, std: 182.842
# 	pitch_mean, mean: 144.014, std: 19.325
# 	pitch_std, mean: 43.200, std: 39.072
# 	rate_syl, mean: 5.418, std: 2.113
# 	rate_vcd, mean: 0.627, std: 0.167
# 	intensity_min, mean: 44.696, std: 7.875
# 	intensity_max, mean: 73.354, std: 3.859
# 	intensity_mean, mean: 63.874, std: 2.752
# 	intensity_std, mean: 6.835, std: 2.160
# 	jitter, mean: 0.014, std: 0.005
# 	shimmer, mean: 0.106, std: 0.032
# 	nhr, mean: 0.139, std: 0.067
#
#
#
# spk_id: 202
# 	pitch_min, mean: 99.699, std: 12.692
# 	pitch_max, mean: 216.072, std: 102.292
# 	pitch_mean, mean: 134.857, std: 14.451
# 	pitch_std, mean: 23.954, std: 18.535
# 	rate_syl, mean: 6.791, std: 2.232
# 	rate_vcd, mean: 0.711, std: 0.126
# 	intensity_min, mean: 42.773, std: 6.269
# 	intensity_max, mean: 72.524, std: 4.729
# 	intensity_mean, mean: 62.332, std: 3.501
# 	intensity_std, mean: 7.307, std: 1.898
# 	jitter, mean: 0.017, std: 0.005
# 	shimmer, mean: 0.116, std: 0.026
# 	nhr, mean: 0.141, std: 0.054
#
#
#
# spk_id: 203
# 	pitch_min, mean: 140.219, std: 29.626
# 	pitch_max, mean: 315.599, std: 128.197
# 	pitch_mean, mean: 191.735, std: 18.111
# 	pitch_std, mean: 34.719, std: 24.723
# 	rate_syl, mean: 5.086, std: 1.845
# 	rate_vcd, mean: 0.730, std: 0.127
# 	intensity_min, mean: 43.922, std: 7.472
# 	intensity_max, mean: 70.242, std: 3.691
# 	intensity_mean, mean: 61.897, std: 3.291
# 	intensity_std, mean: 6.699, std: 2.117
# 	jitter, mean: 0.011, std: 0.003
# 	shimmer, mean: 0.098, std: 0.031
# 	nhr, mean: 0.098, std: 0.052
#
#
#
# spk_id: 302
# 	pitch_min, mean: 121.758, std: 40.320
# 	pitch_max, mean: 332.852, std: 131.230
# 	pitch_mean, mean: 188.745, std: 23.509
# 	pitch_std, mean: 40.634, std: 24.922
# 	rate_syl, mean: 4.672, std: 1.493
# 	rate_vcd, mean: 0.695, std: 0.188
# 	intensity_min, mean: 38.445, std: 7.739
# 	intensity_max, mean: 64.956, std: 3.957
# 	intensity_mean, mean: 55.660, std: 3.948
# 	intensity_std, mean: 6.839, std: 2.424
# 	jitter, mean: 0.012, std: 0.005
# 	shimmer, mean: 0.099, std: 0.033
# 	nhr, mean: 0.117, std: 0.079
#
#
#
# spk_id: 303
# 	pitch_min, mean: 102.554, std: 36.007
# 	pitch_max, mean: 368.643, std: 160.390
# 	pitch_mean, mean: 177.925, std: 28.781
# 	pitch_std, mean: 50.704, std: 32.109
# 	rate_syl, mean: 4.209, std: 1.718
# 	rate_vcd, mean: 0.624, std: 0.174
# 	intensity_min, mean: 39.563, std: 7.095
# 	intensity_max, mean: 69.613, std: 4.116
# 	intensity_mean, mean: 60.429, std: 3.316
# 	intensity_std, mean: 7.390, std: 2.313
# 	jitter, mean: 0.011, std: 0.005
# 	shimmer, mean: 0.084, std: 0.032
# 	nhr, mean: 0.115, std: 0.069
#
#
#
# spk_id: 304
# 	pitch_min, mean: 102.338, std: 20.913
# 	pitch_max, mean: 319.443, std: 165.463
# 	pitch_mean, mean: 156.290, std: 28.344
# 	pitch_std, mean: 43.974, std: 34.177
# 	rate_syl, mean: 4.611, std: 1.367
# 	rate_vcd, mean: 0.564, std: 0.172
# 	intensity_min, mean: 40.595, std: 7.037
# 	intensity_max, mean: 76.398, std: 5.014
# 	intensity_mean, mean: 63.008, std: 3.744
# 	intensity_std, mean: 9.161, std: 2.031
# 	jitter, mean: 0.013, std: 0.005
# 	shimmer, mean: 0.110, std: 0.030
# 	nhr, mean: 0.182, std: 0.092
#
#
#
# spk_id: 305
# 	pitch_min, mean: 98.631, std: 25.773
# 	pitch_max, mean: 284.037, std: 136.813
# 	pitch_mean, mean: 145.642, std: 23.321
# 	pitch_std, mean: 33.005, std: 24.157
# 	rate_syl, mean: 4.626, std: 1.676
# 	rate_vcd, mean: 0.599, std: 0.161
# 	intensity_min, mean: 44.706, std: 7.221
# 	intensity_max, mean: 80.215, std: 4.648
# 	intensity_mean, mean: 69.109, std: 4.131
# 	intensity_std, mean: 8.803, std: 2.146
# 	jitter, mean: 0.014, std: 0.007
# 	shimmer, mean: 0.093, std: 0.033
# 	nhr, mean: 0.133, std: 0.070

# %%
# run script to create auxiliary tables (involves randomness!)
with open('../sql/aux_tables.sql') as sql_file:
    sql_script = ''.join(sql_file.readlines())
    with sqlite3.connect(db_fname) as conn:
        conn.cursor().executescript(sql_script)
